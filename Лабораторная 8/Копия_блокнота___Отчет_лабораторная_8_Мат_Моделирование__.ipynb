# %% [markdown]
# ---
# ___
# <h1 align="center">Российский государственный университет дружбы народов им. Патриса Лумумбы</h1>
# <h3 align="center">Кафедра математического моделирования и искусственного интеллекта</h3>
# <br>
# <br>
# <br>
# <br>
# <h2 align="center">Дисциплина: «Математическое моделирование»</h2>
# <br>
# <h1 align="center">ОТЧЕТ</h1>
# <h2 align="center">по лабораторной работе 8 </h2>
# <br>
# <br>
# <br>
# <br>
#
# <table width="100%" style="border: none; border-collapse: collapse;">
#   <tr>
#     <td width="50%" style="border: none; vertical-align: top; padding-left: 5%;">
#       <p><b>Выполнила:</b></p>
#       <p>Студентка группы НПИбд-02-23</p>
#       <p><u>Астахова Марина Дмитриевна</u></p>
#
#   </tr>
# </table>
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <h3 align="center">Москва</h3>
# <h3 align="center">2026</h3>
# ___

# %% [markdown]
# </div>
#
# ## Цель выполнения лабораторной работы
#
# Исследовать динамику изменения объемов продаж двух фирм, производящих взаимозаменяемые товары, в условиях конкурентной борьбы, ограниченной рыночными методами (случай 1), и при дополнительном учете социально-психологических факторов, влияющих на предпочтения потребителей (случай 2).
#
#
# ## Задачи
#
# > 1. ***Рассчитать коэффициенты моделей на основе заданных экономических параметров.***
#
# > 2. ***Решить системы дифференциальных уравнений, описывающих динамику объемов продаж для двух случаев.***
#
# > 3. ***Построить графики изменения объемов продаж (оборотных средств) фирм во времени.***
#
# > 4. ***Сравнить поведение систем в двух случаях и сделать вывод о влиянии социально-психологического фактора на конкурентную динамику.***
#
# </div>

# %% [markdown]
# ![вар_8.1.PNG](data:image/png;base64,...)

# %% [markdown]
# ![вар_8.2.PNG](data:image/png;base64,...)

# %% [markdown]
# ![вар_8.3.PNG](data:image/png;base64,...)

# %% [markdown]
# ![вар_8.4.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Выполнение

# %% [markdown]
# ### ***Общие параметры***

# %%
p_cr = 20;
N = 23;
q = 1;
tau1 = 16;
tau2 = 19;
p1 = 13;
p2 = 11;

# %% [markdown]
# ### ***Расчет коэффициентов***

# %%
a1 = p_cr/(tau1*tau1*p1*p1*N*q);
a2 = p_cr/(tau2*tau2*p2*p2*N*q);
b = p_cr/(tau1*tau1*tau2*tau2*p1*p1*p2*p2*N*q);
c1 = (p_cr - p1)/(tau1*p1);
c2 = (p_cr - p2)/(tau2*p2);

# %% [markdown]
# ### ***Начальные условия и время***

# %%
theta0 = 0;
x0 = [2.5; 1.8];
theta = 0:0.01:30;

# %% [markdown]
# ### ***Случай 1: без социально-психологических факторов***

# %%
function dx = syst1(theta, x)
    dx(1) = x(1) - (a1/c1)*x(1)*x(1) - (b/c1)*x(1)*x(2);
    dx(2) = (c2/c1)*x(2) - (a2/c1)*x(2)*x(2) - (b/c1)*x(1)*x(2);
endfunction

# %% [markdown]
# ### ***Случай 2: с социально-психологическими факторами***

# %%
function dx = syst2(theta, x)
    dx(1) = x(1) - (a1/c1)*x(1)*x(1) - ((b/c1) + 0.0017)*x(1)*x(2);
    dx(2) = (c2/c1)*x(2) - (a2/c1)*x(2)*x(2) - (b/c1)*x(1)*x(2);
endfunction

# %% [markdown]
# ### ***Решения***

# %%
y1 = ode(x0, theta0, theta, syst1);
y2 = ode(x0, theta0, theta, syst2);

# %% [markdown]
# ### ***Визуализация***

# %%
clf;
subplot(2,1,1);
plot(theta, y1(1,:), 'r', theta, y1(2,:), 'b');
xtitle('Случай 1: Без социально-психологических факторов', '\theta', 'Объем продаж');
legend(['Фирма 1 (M_1)'; 'Фирма 2 (M_2)']);
xgrid(1);

subplot(2,1,2);
plot(theta, y2(1,:), 'r', theta, y2(2,:), 'b');
xtitle('Случай 2: С социально-психологическими факторами', '\theta', 'Объем продаж');
legend(['Фирма 1 (M_1)'; 'Фирма 2 (M_2)']);
xgrid(1);

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Итог работы
#
# В ходе выполнения работы исследована динамика изменения объемов продаж двух конкурирующих фирм на основе двух математических моделей.
#
# 1. **Случай 1** описывает конкурентную борьбу только рыночными методами (изменение себестоимости и производственного цикла). Решение системы дифференциальных уравнений показало, что объемы продаж обеих фирм стремятся к стационарным состояниям, причем фирма с более низкой себестоимостью имеет преимущество.
#
# 2. **Случай 2** дополнительно учитывает социально-психологический фактор, формирующий общественное предпочтение товара фирмы 1. Введение этого фактора усиливает конкурентные позиции первой фирмы, изменяя динамику взаимодействия.
#
# ***Вывод:*** социально-психологические факторы способны существенно влиять на конкурентное равновесие, что подтверждается различием в траекториях объемов продаж на построенных графиках.
